# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# # List for holding lat_lngs and cities
# lat_lngs = []
# cities = []

# # Create a set of random lat and lng combinations
# lats = np.random.uniform(lat_range[0], lat_range[1], size=10) #reduced to generate smaller # for initial run
# lngs = np.random.uniform(lng_range[0], lng_range[1], size=10)
# lat_lngs = zip(lats, lngs)

# # Identify nearest city for each lat, lng combination
# for lat_lng in lat_lngs:
#     city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
#     # If the city is unique, then add it to a our cities list
#     if city not in cities:
#         cities.append(city)

# # Print the city count to confirm sufficient count
# len(cities)
# Out:
# 10

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500) 
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# #create the url call after setting the config using the API saved above
# url = "http://api.openweathermap.org/data/2.5/weather?"
# #city = "Tulum" #run a test prior to building the for loop

# # Build query URL to get the weather data for city, will create a new variable for cities list once test complete
# query_url = url + "appid=" + weather_api_key + "&q=" + city

# %%
# Get weather data to test one prior to building for loop
# weather_response = requests.get(query_url)
# weather_json = weather_response.json()

# Get the weather data from the response
#print(f"The weather API responded with: {weather_json}.") #weather for Visnes from reduced random list
# Out:
# The weather API responded with: {'coord': {'lon': -87.4667, 'lat': 20.2167}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 303.15, 'feels_like': 306.39, 'temp_min': 303.15, 'temp_max': 303.15, 'pressure': 1014, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 5.66, 'deg': 100}, 'clouds': {'all': 20}, 'dt': 1619363540, 'sys': {'type': 1, 'id': 7130, 'country': 'MX', 'sunrise': 1619349835, 'sunset': 1619395878}, 'timezone': -18000, 'id': 3515040, 'name': 'Tulum', 'cod': 200}.

# %%
#print(f"City name and number: ") from test call
#print(weather_json['name'],weather_json['id'])
# Out:
# City name and number:
# Tulum 3515040

# %%
# #Use a for loop to create a series of API calls then print each city as it's being processed from test run

# city = 0

# for city in cities:
#     url = "http://api.openweathermap.org/data/2.5/weather?"
#     query_url = url + "appid=" + weather_api_key + "&q=" + city 
#     weather_response = requests.get(query_url)
#     weather_json = weather_response.json()

#     try:    #Include a try/except for any items that have an error
        
#         print(f"City name and number: ") 
#         print(weather_json['name'],weather_json['id'])
        
#     except (KeyError, IndexError):
#         print("Missing field/result... skipping.")
        
# pass

# #start with a sample before calling the larger list
# Out:
# City name and number:
# Kavieng 2094342
# City name and number:
# Aksu 1529660
# City name and number:
# Missing field/result... skipping.
# City name and number:
# Ushuaia 3833367
# City name and number:
# Toguchin 1489508
# City name and number:
# Valenzano 6541260
# City name and number:
# Jalpan 3526601
# City name and number:
# Geraldton 2070998
# City name and number:
# Yulara 6355222
# City name and number:
# Khatanga 2022572

# %%
# #Use a for loop to create a series of API calls then print each city as it's being processed
# Determined a need to create empty lists to store the data

city_name = []
country = []
date = []
lat = []
lon = []
clouds = []
humidity = []
max_temp = []
wind_spd = []

index_counter = 0
set_counter = 1


city = 0

url = "http://api.openweathermap.org/data/2.5/weather?"

#need to count within the for loop while iterating through the rows
for index, city in enumerate(cities, start = 1):
    try:
        query_url = f"{url}appid={weather_api_key}&q=" 
        response_json = requests.get(query_url + city).json()
        city_name.append(response_json["name"])
        country.append(response_json["sys"]["country"])
        date.append(response_json["dt"])
        lat.append(response_json["coord"]["lat"])
        lon.append(response_json["coord"]["lon"])
        clouds.append(response_json["clouds"]["all"])
        humidity.append(response_json["main"]["humidity"])
        max_temp.append(response_json['main']['temp_max'])
        wind_spd.append(response_json["wind"]["speed"])
        
        index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")
    
#     weather_response = requests.get(query_url)
#     weather_json = weather_response.json()

#     try:    #Include a try/except for any items that have an error
        
#         print(f"City name and number: ") 
#         print(weather_json['name'],weather_json['id'])
        
#     except (KeyError, IndexError):
#         print("Missing field/result... skipping.")
        
pass #tested on small dataset, before running on larger one
# Out:
# Processing Record 1 of Set 1 : alta floresta
# Processing Record 2 of Set 1 : sur
# Processing Record 3 of Set 1 : rikitea
# Processing Record 4 of Set 1 : puerto ayora
# Processing Record 5 of Set 1 : kelowna
# Processing Record 6 of Set 1 : touros
# Processing Record 7 of Set 1 : havelock
# Processing Record 8 of Set 1 : okha
# Processing Record 9 of Set 1 : ixtapa
# City not found. Skipping...
# Processing Record 10 of Set 1 : tahta
# Processing Record 11 of Set 1 : santiago del estero
# Processing Record 12 of Set 1 : kavieng
# Processing Record 13 of Set 1 : tateyama
# Processing Record 14 of Set 1 : iquique
# Processing Record 15 of Set 1 : mount isa
# Processing Record 16 of Set 1 : souillac
# Processing Record 17 of Set 1 : camaqua
# Processing Record 18 of Set 1 : cacimba de dentro
# City not found. Skipping...
# Processing Record 19 of Set 1 : chuy
# Processing Record 20 of Set 1 : codrington
# Processing Record 21 of Set 1 : saint george
# City not found. Skipping...
# Processing Record 22 of Set 1 : butaritari
# Processing Record 23 of Set 1 : qaanaaq
# Processing Record 24 of Set 1 : montauban
# Processing Record 25 of Set 1 : ust-kut
# Processing Record 26 of Set 1 : kavaratti
# City not found. Skipping...
# Processing Record 27 of Set 1 : bluff
# Processing Record 28 of Set 1 : richards bay
# Processing Record 29 of Set 1 : longyearbyen
# Processing Record 30 of Set 1 : jamestown
# Processing Record 31 of Set 1 : beringovskiy
# Processing Record 32 of Set 1 : bengkulu
# City not found. Skipping...
# Processing Record 33 of Set 1 : atuona
# Processing Record 34 of Set 1 : faanui
# City not found. Skipping...
# Processing Record 35 of Set 1 : new norfolk
# Processing Record 36 of Set 1 : paamiut
# Processing Record 37 of Set 1 : hilo
# Processing Record 38 of Set 1 : khatanga
# Processing Record 39 of Set 1 : bone
# Processing Record 40 of Set 1 : nalut
# Processing Record 41 of Set 1 : tuatapere
# Processing Record 42 of Set 1 : los llanos de aridane
# Processing Record 43 of Set 1 : faya
# Processing Record 44 of Set 1 : qixia
# Processing Record 45 of Set 1 : coquimbo
# Processing Record 46 of Set 1 : lethem
# Processing Record 47 of Set 1 : chicama
# Processing Record 48 of Set 1 : nanortalik
# Processing Record 49 of Set 1 : pevek
# Processing Record 50 of Set 1 : arraial do cabo
# Processing Record 51 of Set 1 : bathsheba
# Processing Record 52 of Set 1 : narsaq
# Processing Record 53 of Set 1 : iqaluit
# Processing Record 54 of Set 1 : norman wells
# Processing Record 55 of Set 1 : kodiak
# Processing Record 56 of Set 1 : mataura
# Processing Record 57 of Set 1 : hobart
# Processing Record 58 of Set 1 : port alfred
# Processing Record 59 of Set 1 : grindavik
# City not found. Skipping...
# Processing Record 60 of Set 1 : cayenne
# Processing Record 61 of Set 1 : barrow
# Processing Record 62 of Set 1 : emerald
# Processing Record 63 of Set 1 : saint-philippe
# Processing Record 64 of Set 1 : dubove
# Processing Record 65 of Set 1 : tall kayf
# Processing Record 66 of Set 1 : jyvaskyla
# Processing Record 67 of Set 1 : hofn
# City not found. Skipping...
# Processing Record 68 of Set 1 : esperance
# Processing Record 69 of Set 1 : tura
# City not found. Skipping...
# Processing Record 70 of Set 1 : hami
# Processing Record 71 of Set 1 : nikolskoye
# City not found. Skipping...
# Processing Record 72 of Set 1 : mucuri
# Processing Record 73 of Set 1 : carnarvon
# Processing Record 74 of Set 1 : treinta y tres
# Processing Record 75 of Set 1 : yellowknife
# Processing Record 76 of Set 1 : srandakan
# Processing Record 77 of Set 1 : upernavik
# Processing Record 78 of Set 1 : ust-tsilma
# Processing Record 79 of Set 1 : tasiilaq
# Processing Record 80 of Set 1 : neiafu
# Processing Record 81 of Set 1 : castro
# Processing Record 82 of Set 1 : luderitz
# Processing Record 83 of Set 1 : alofi
# City not found. Skipping...
# Processing Record 84 of Set 1 : augusto correa
# Processing Record 85 of Set 1 : avarua
# Processing Record 86 of Set 1 : rocha
# City not found. Skipping...
# Processing Record 87 of Set 1 : punta arenas
# Processing Record 88 of Set 1 : talnakh
# Processing Record 89 of Set 1 : sao joao da barra
# Processing Record 90 of Set 1 : vaini
# Processing Record 91 of Set 1 : merauke
# Processing Record 92 of Set 1 : cidreira
# Processing Record 93 of Set 1 : thompson
# Processing Record 94 of Set 1 : busselton
# Processing Record 95 of Set 1 : katsuura
# Processing Record 96 of Set 1 : taylorville
# Processing Record 97 of Set 1 : santa isabel do rio negro
# Processing Record 98 of Set 1 : tuktoyaktuk
# Processing Record 99 of Set 1 : dikson
# Processing Record 100 of Set 1 : cape town
# City not found. Skipping...
# Processing Record 101 of Set 1 : benguela
# Processing Record 102 of Set 1 : albany
# Processing Record 103 of Set 1 : kanye
# Processing Record 104 of Set 1 : batagay-alyta
# Processing Record 105 of Set 1 : luwuk
# Processing Record 106 of Set 1 : cuamba
# Processing Record 107 of Set 1 : ushuaia
# Processing Record 108 of Set 1 : ucluelet
# Processing Record 109 of Set 1 : oksfjord
# Processing Record 110 of Set 1 : ribeira grande
# Processing Record 111 of Set 1 : bethel
# Processing Record 112 of Set 1 : leningradskiy
# Processing Record 113 of Set 1 : zyryanka
# Processing Record 114 of Set 1 : peniche
# Processing Record 115 of Set 1 : husavik
# Processing Record 116 of Set 1 : birobidzhan
# Processing Record 117 of Set 1 : lima
# Processing Record 118 of Set 1 : hazorasp
# Processing Record 119 of Set 1 : vao
# Processing Record 120 of Set 1 : buseresere
# Processing Record 121 of Set 1 : severo-kurilsk
# Processing Record 122 of Set 1 : kjollefjord
# Processing Record 123 of Set 1 : lagoa
# Processing Record 124 of Set 1 : kirakira
# Processing Record 125 of Set 1 : hervey bay
# Processing Record 126 of Set 1 : sambava
# Processing Record 127 of Set 1 : kirando
# Processing Record 128 of Set 1 : maceio
# Processing Record 129 of Set 1 : turka
# Processing Record 130 of Set 1 : paita
# Processing Record 131 of Set 1 : georgiyevka
# Processing Record 132 of Set 1 : hithadhoo
# Processing Record 133 of Set 1 : hermanus
# Processing Record 134 of Set 1 : oranjestad
# Processing Record 135 of Set 1 : sinjai
# Processing Record 136 of Set 1 : sulangan
# Processing Record 137 of Set 1 : gizo
# Processing Record 138 of Set 1 : san ramon
# Processing Record 139 of Set 1 : kutum
# City not found. Skipping...
# Processing Record 140 of Set 1 : hovd
# Processing Record 141 of Set 1 : tsiroanomandidy
# Processing Record 142 of Set 1 : tessalit
# City not found. Skipping...
# Processing Record 143 of Set 1 : airai
# Processing Record 144 of Set 1 : emba
# Processing Record 145 of Set 1 : victoria
# Processing Record 146 of Set 1 : whitehorse
# Processing Record 147 of Set 1 : sabang
# Processing Record 148 of Set 1 : sampit
# Processing Record 149 of Set 1 : chapais
# Processing Record 150 of Set 1 : binghamton
# Processing Record 151 of Set 1 : sarangani
# City not found. Skipping...
# Processing Record 152 of Set 1 : flinders
# Processing Record 153 of Set 1 : hasaki
# Processing Record 154 of Set 1 : lasa
# Processing Record 155 of Set 1 : lebu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 156 of Set 1 : provideniya
# Processing Record 157 of Set 1 : te anau
# Processing Record 158 of Set 1 : venice
# Processing Record 159 of Set 1 : abu zabad
# Processing Record 160 of Set 1 : igarka
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 161 of Set 1 : mao
# Processing Record 162 of Set 1 : maine-soroa
# City not found. Skipping...
# Processing Record 163 of Set 1 : broome
# Processing Record 164 of Set 1 : kenora
# Processing Record 165 of Set 1 : kasulu
# Processing Record 166 of Set 1 : mackay
# City not found. Skipping...
# Processing Record 167 of Set 1 : portland
# Processing Record 168 of Set 1 : fenwick
# Processing Record 169 of Set 1 : cherskiy
# Processing Record 170 of Set 1 : san andres
# Processing Record 171 of Set 1 : popondetta
# City not found. Skipping...
# Processing Record 172 of Set 1 : torbay
# Processing Record 173 of Set 1 : laguna
# Processing Record 174 of Set 1 : cabo san lucas
# Processing Record 175 of Set 1 : shingu
# Processing Record 176 of Set 1 : staryy nadym
# Processing Record 177 of Set 1 : ronneby
# Processing Record 178 of Set 1 : monteagudo
# Processing Record 179 of Set 1 : leh
# Processing Record 180 of Set 1 : starobesheve
# Processing Record 181 of Set 1 : lorengau
# Processing Record 182 of Set 1 : inirida
# Processing Record 183 of Set 1 : innisfail
# Processing Record 184 of Set 1 : kharan
# Processing Record 185 of Set 1 : darasun
# City not found. Skipping...
# Processing Record 186 of Set 1 : bozeman
# Processing Record 187 of Set 1 : zhongshu
# Processing Record 188 of Set 1 : kaitangata
# Processing Record 189 of Set 1 : ponta do sol
# Processing Record 190 of Set 1 : lufilufi
# Processing Record 191 of Set 1 : mahebourg
# Processing Record 192 of Set 1 : vostok
# Processing Record 193 of Set 1 : canico
# Processing Record 194 of Set 1 : udalguri
# Processing Record 195 of Set 1 : guatire
# Processing Record 196 of Set 1 : ilulissat
# Processing Record 197 of Set 1 : djambala
# Processing Record 198 of Set 1 : ruston
# Processing Record 199 of Set 1 : kurayoshi
# Processing Record 200 of Set 1 : hambantota
# Processing Record 201 of Set 1 : guerrero negro
# Processing Record 202 of Set 1 : sarakhs
# Processing Record 203 of Set 1 : constitucion
# Processing Record 204 of Set 1 : barcelos
# Processing Record 205 of Set 1 : kharitonovo
# Processing Record 206 of Set 1 : puerto baquerizo moreno
# Processing Record 207 of Set 1 : bredasdorp
# Processing Record 208 of Set 1 : rio gallegos
# Processing Record 209 of Set 1 : tiksi
# Processing Record 210 of Set 1 : goundam
# Processing Record 211 of Set 1 : huarmey
# Processing Record 212 of Set 1 : hamilton
# Processing Record 213 of Set 1 : mahibadhoo
# Processing Record 214 of Set 1 : vila franca do campo
# Processing Record 215 of Set 1 : port elizabeth
# Processing Record 216 of Set 1 : pitimbu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 217 of Set 1 : kapaa
# Processing Record 218 of Set 1 : aklavik
# Processing Record 219 of Set 1 : saint-augustin
# Processing Record 220 of Set 1 : port hardy
# Processing Record 221 of Set 1 : nador
# Processing Record 222 of Set 1 : antonina
# Processing Record 223 of Set 1 : shenjiamen
# City not found. Skipping...
# Processing Record 224 of Set 1 : kahului
# Processing Record 225 of Set 1 : varkkallai
# City not found. Skipping...
# Processing Record 226 of Set 1 : boden
# Processing Record 227 of Set 1 : tarauaca
# Processing Record 228 of Set 1 : volnovakha
# Processing Record 229 of Set 1 : sitka
# Processing Record 230 of Set 1 : henties bay
# Processing Record 231 of Set 1 : arman
# Processing Record 232 of Set 1 : selma
# Processing Record 233 of Set 1 : sabha
# City not found. Skipping...
# Processing Record 234 of Set 1 : sigli
# Processing Record 235 of Set 1 : richmond hill
# Processing Record 236 of Set 1 : hienghene
# City not found. Skipping...
# Processing Record 237 of Set 1 : kayerkan
# Processing Record 238 of Set 1 : boa esperanca
# Processing Record 239 of Set 1 : pindiga
# Processing Record 240 of Set 1 : praya
# Processing Record 241 of Set 1 : mar del plata
# Processing Record 242 of Set 1 : east london
# Processing Record 243 of Set 1 : elko
# Processing Record 244 of Set 1 : anaconda
# Processing Record 245 of Set 1 : gostyn
# City not found. Skipping...
# Processing Record 246 of Set 1 : shestakovo
# Processing Record 247 of Set 1 : okato
# Processing Record 248 of Set 1 : berlevag
# Processing Record 249 of Set 1 : neuquen
# Processing Record 250 of Set 1 : baykit
# City not found. Skipping...
# Processing Record 251 of Set 1 : mosetse
# Processing Record 252 of Set 1 : dunedin
# Processing Record 253 of Set 1 : chuka
# Processing Record 254 of Set 1 : khash
# Processing Record 255 of Set 1 : bikaner
# Processing Record 256 of Set 1 : vallenar
# Processing Record 257 of Set 1 : esil
# Processing Record 258 of Set 1 : kolosovka
# Processing Record 259 of Set 1 : evensk
# Processing Record 260 of Set 1 : madras
# Processing Record 261 of Set 1 : jalu
# Processing Record 262 of Set 1 : togur
# Processing Record 263 of Set 1 : murray bridge
# Processing Record 264 of Set 1 : den helder
# Processing Record 265 of Set 1 : roald
# Processing Record 266 of Set 1 : senneterre
# Processing Record 267 of Set 1 : fairbanks
# Processing Record 268 of Set 1 : lianran
# Processing Record 269 of Set 1 : quatre cocos
# Processing Record 270 of Set 1 : banda aceh
# Processing Record 271 of Set 1 : cooma
# Processing Record 272 of Set 1 : waipawa
# Processing Record 273 of Set 1 : vondrozo
# Processing Record 274 of Set 1 : pirgos
# City not found. Skipping...
# Processing Record 275 of Set 1 : praia da vitoria
# Processing Record 276 of Set 1 : caravelas
# Processing Record 277 of Set 1 : aasiaat
# Processing Record 278 of Set 1 : georgetown
# Processing Record 279 of Set 1 : panacan
# Processing Record 280 of Set 1 : porto murtinho
# Processing Record 281 of Set 1 : naze
# Processing Record 282 of Set 1 : sawtell
# City not found. Skipping...
# Processing Record 283 of Set 1 : kuah
# Processing Record 284 of Set 1 : lai
# Processing Record 285 of Set 1 : touho
# Processing Record 286 of Set 1 : namibe
# Processing Record 287 of Set 1 : boa vista
# Processing Record 288 of Set 1 : asosa
# Processing Record 289 of Set 1 : sorong
# Processing Record 290 of Set 1 : nuqui
# Processing Record 291 of Set 1 : itarema
# Processing Record 292 of Set 1 : dingle
# Processing Record 293 of Set 1 : geraldton
# Processing Record 294 of Set 1 : olafsvik
# Processing Record 295 of Set 1 : sorland
# Processing Record 296 of Set 1 : tautira
# Processing Record 297 of Set 1 : bridlington
# Processing Record 298 of Set 1 : saldanha
# City not found. Skipping...
# Processing Record 299 of Set 1 : buala
# Processing Record 300 of Set 1 : davila
# Processing Record 301 of Set 1 : isangel
# Processing Record 302 of Set 1 : port augusta
# Processing Record 303 of Set 1 : wawa
# Processing Record 304 of Set 1 : rundu
# Processing Record 305 of Set 1 : khorinsk
# Processing Record 306 of Set 1 : necochea
# Processing Record 307 of Set 1 : makakilo city
# Processing Record 308 of Set 1 : tomatlan
# Processing Record 309 of Set 1 : kifri
# Processing Record 310 of Set 1 : kosovska mitrovica
# Processing Record 311 of Set 1 : saskylakh
# Processing Record 312 of Set 1 : state college
# Processing Record 313 of Set 1 : vestmanna
# Processing Record 314 of Set 1 : clyde river
# Processing Record 315 of Set 1 : gurupa
# Processing Record 316 of Set 1 : riachao
# City not found. Skipping...
# Processing Record 317 of Set 1 : korla
# Processing Record 318 of Set 1 : sibolga
# Processing Record 319 of Set 1 : nishihara
# Processing Record 320 of Set 1 : buluang
# Processing Record 321 of Set 1 : lazurne
# Processing Record 322 of Set 1 : port lincoln
# Processing Record 323 of Set 1 : springdale
# Processing Record 324 of Set 1 : bay roberts
# Processing Record 325 of Set 1 : wuwei
# Processing Record 326 of Set 1 : ca mau
# Processing Record 327 of Set 1 : kinsale
# Processing Record 328 of Set 1 : sinnamary
# Processing Record 329 of Set 1 : portobelo
# Processing Record 330 of Set 1 : voh
# Processing Record 331 of Set 1 : machinga
# Processing Record 332 of Set 1 : vardo
# Processing Record 333 of Set 1 : rio cuarto
# Processing Record 334 of Set 1 : seoul
# Processing Record 335 of Set 1 : sisimiut
# Processing Record 336 of Set 1 : chulman
# Processing Record 337 of Set 1 : kuandian
# Processing Record 338 of Set 1 : mangan
# Processing Record 339 of Set 1 : mikhaylovskoye
# Processing Record 340 of Set 1 : virginia beach
# Processing Record 341 of Set 1 : cabedelo
# Processing Record 342 of Set 1 : teguise
# Processing Record 343 of Set 1 : tonekabon
# Processing Record 344 of Set 1 : darab
# Processing Record 345 of Set 1 : sept-iles
# Processing Record 346 of Set 1 : carutapera
# Processing Record 347 of Set 1 : mettupalayam
# Processing Record 348 of Set 1 : bartica
# Processing Record 349 of Set 1 : bima
# Processing Record 350 of Set 1 : padang
# Processing Record 351 of Set 1 : kamenka
# Processing Record 352 of Set 1 : gaziantep
# City not found. Skipping...
# Processing Record 353 of Set 1 : port said
# Processing Record 354 of Set 1 : tokmak
# Processing Record 355 of Set 1 : kloulklubed
# Processing Record 356 of Set 1 : madingou
# Processing Record 357 of Set 1 : rumuruti
# Processing Record 358 of Set 1 : sansepolcro
# Processing Record 359 of Set 1 : tadine
# Processing Record 360 of Set 1 : coihaique
# Processing Record 361 of Set 1 : iquitos
# Processing Record 362 of Set 1 : atar
# Processing Record 363 of Set 1 : nantucket
# Processing Record 364 of Set 1 : port macquarie
# Processing Record 365 of Set 1 : concordia
# Processing Record 366 of Set 1 : vanavara
# Processing Record 367 of Set 1 : plouzane
# Processing Record 368 of Set 1 : pisco
# City not found. Skipping...
# Processing Record 369 of Set 1 : udachnyy
# Processing Record 370 of Set 1 : axim
# Processing Record 371 of Set 1 : puerto palomas
# Processing Record 372 of Set 1 : konotop
# Processing Record 373 of Set 1 : the valley
# Processing Record 374 of Set 1 : ahipara
# Processing Record 375 of Set 1 : christchurch
# Processing Record 376 of Set 1 : rawson
# Processing Record 377 of Set 1 : alice springs
# Processing Record 378 of Set 1 : cerrik
# Processing Record 379 of Set 1 : knin
# Processing Record 380 of Set 1 : srednekolymsk
# Processing Record 381 of Set 1 : ambon
# Processing Record 382 of Set 1 : uthal
# Processing Record 383 of Set 1 : mitu
# Processing Record 384 of Set 1 : awjilah
# Processing Record 385 of Set 1 : champerico
# Processing Record 386 of Set 1 : isiro
# City not found. Skipping...
# Processing Record 387 of Set 1 : khorixas
# Processing Record 388 of Set 1 : vanimo
# Processing Record 389 of Set 1 : svetlogorsk
# City not found. Skipping...
# Processing Record 390 of Set 1 : zhoucheng
# Processing Record 391 of Set 1 : peleduy
# Processing Record 392 of Set 1 : pa daet
# Processing Record 393 of Set 1 : vilyuysk
# Processing Record 394 of Set 1 : manzhouli
# Processing Record 395 of Set 1 : semirom
# City not found. Skipping...
# Processing Record 396 of Set 1 : gamba
# Processing Record 397 of Set 1 : ust-nera
# Processing Record 398 of Set 1 : sistranda
# Processing Record 399 of Set 1 : bismarck
# Processing Record 400 of Set 1 : van
# Processing Record 401 of Set 1 : balikpapan
# Processing Record 402 of Set 1 : myitkyina
# Processing Record 403 of Set 1 : mocuba
# Processing Record 404 of Set 1 : hitachi
# Processing Record 405 of Set 1 : rodoc
# Processing Record 406 of Set 1 : taltal
# Processing Record 407 of Set 1 : verkhnyaya inta
# Processing Record 408 of Set 1 : bilibino
# Processing Record 409 of Set 1 : upington
# Processing Record 410 of Set 1 : yerbogachen
# Processing Record 411 of Set 1 : winterberg
# Processing Record 412 of Set 1 : teahupoo
# Processing Record 413 of Set 1 : hobyo
# Processing Record 414 of Set 1 : shaygino
# Processing Record 415 of Set 1 : takapau
# Processing Record 416 of Set 1 : sao filipe
# Processing Record 417 of Set 1 : vysokogornyy
# Processing Record 418 of Set 1 : la ronge
# Processing Record 419 of Set 1 : aguimes
# Processing Record 420 of Set 1 : dandong
# City not found. Skipping...
# Processing Record 421 of Set 1 : forrest city
# Processing Record 422 of Set 1 : harer
# City not found. Skipping...
# Processing Record 423 of Set 1 : ostrovnoy
# Processing Record 424 of Set 1 : klaksvik
# Processing Record 425 of Set 1 : san patricio
# Processing Record 426 of Set 1 : esfarayen
# Processing Record 427 of Set 1 : honningsvag
# City not found. Skipping...
# Processing Record 428 of Set 1 : kalevala
# Processing Record 429 of Set 1 : beloha
# Processing Record 430 of Set 1 : barma
# Processing Record 431 of Set 1 : lompoc
# Processing Record 432 of Set 1 : vestmannaeyjar
# Processing Record 433 of Set 1 : mayya
# Processing Record 434 of Set 1 : aquiraz
# Processing Record 435 of Set 1 : barinas
# Processing Record 436 of Set 1 : hirara
# Processing Record 437 of Set 1 : ko samui
# Processing Record 438 of Set 1 : payo
# Processing Record 439 of Set 1 : bara
# Processing Record 440 of Set 1 : bambous virieux
# Processing Record 441 of Set 1 : oda
# Processing Record 442 of Set 1 : vrangel
# Processing Record 443 of Set 1 : lavrentiya
# Processing Record 444 of Set 1 : terrace
# Processing Record 445 of Set 1 : chalus
# Processing Record 446 of Set 1 : sioux lookout
# Processing Record 447 of Set 1 : nemuro
# Processing Record 448 of Set 1 : custoias
# Processing Record 449 of Set 1 : mayo
# Processing Record 450 of Set 1 : santo amaro
# Processing Record 451 of Set 1 : kisangani
# Processing Record 452 of Set 1 : aksarka
# Processing Record 453 of Set 1 : grenada
# Processing Record 454 of Set 1 : port hedland
# Processing Record 455 of Set 1 : mateare
# Processing Record 456 of Set 1 : nokaneng
# Processing Record 457 of Set 1 : chota
# City not found. Skipping...
# Processing Record 458 of Set 1 : kannangad
# Processing Record 459 of Set 1 : bhainsdehi
# Processing Record 460 of Set 1 : ramshir
# Processing Record 461 of Set 1 : rock sound
# Processing Record 462 of Set 1 : san policarpo
# Processing Record 463 of Set 1 : coos bay
# Processing Record 464 of Set 1 : tilichiki
# Processing Record 465 of Set 1 : vila velha
# Processing Record 466 of Set 1 : buraydah
# Processing Record 467 of Set 1 : baiyin
# Processing Record 468 of Set 1 : tabalosos
# Processing Record 469 of Set 1 : maiduguri
# Processing Record 470 of Set 1 : boli
# Processing Record 471 of Set 1 : umm lajj
# Processing Record 472 of Set 1 : urengoy
# Processing Record 473 of Set 1 : pingliang
# Processing Record 474 of Set 1 : koubia
# Processing Record 475 of Set 1 : aktash
# Processing Record 476 of Set 1 : khvoynaya
# Processing Record 477 of Set 1 : sulphur
# Processing Record 478 of Set 1 : hohhot
# Processing Record 479 of Set 1 : wittmund
# Processing Record 480 of Set 1 : zalantun
# Processing Record 481 of Set 1 : ugoofaaru
# Processing Record 482 of Set 1 : mariental
# City not found. Skipping...
# Processing Record 483 of Set 1 : ahuimanu
# Processing Record 484 of Set 1 : lock haven
# Processing Record 485 of Set 1 : takoradi
# Processing Record 486 of Set 1 : chokurdakh
# Processing Record 487 of Set 1 : tommot
# Processing Record 488 of Set 1 : eyl
# Processing Record 489 of Set 1 : slave lake
# Processing Record 490 of Set 1 : muros
# Processing Record 491 of Set 1 : kanniyakumari
# Processing Record 492 of Set 1 : tefe
# Processing Record 493 of Set 1 : vina del mar
# Processing Record 494 of Set 1 : sobolevo
# Processing Record 495 of Set 1 : panaba
# Processing Record 496 of Set 1 : beamsville
# Processing Record 497 of Set 1 : pangnirtung
# Processing Record 498 of Set 1 : burnie
# Processing Record 499 of Set 1 : riyadh
# Processing Record 500 of Set 1 : atasu
# Processing Record 501 of Set 1 : ambilobe
# Processing Record 502 of Set 1 : imeni poliny osipenko
# Processing Record 503 of Set 1 : arlit
# Processing Record 504 of Set 1 : sangar
# Processing Record 505 of Set 1 : skjervoy
# Processing Record 506 of Set 1 : rajapolah
# Processing Record 507 of Set 1 : pauri
# Processing Record 508 of Set 1 : guiratinga
# Processing Record 509 of Set 1 : nara
# City not found. Skipping...
# Processing Record 510 of Set 1 : bikin
# Processing Record 511 of Set 1 : komsomolskiy
# Processing Record 512 of Set 1 : birjand
# Processing Record 513 of Set 1 : bakel
# Processing Record 514 of Set 1 : bilma
# Processing Record 515 of Set 1 : pasni
# Processing Record 516 of Set 1 : mafinga
# Processing Record 517 of Set 1 : marsh harbour
# Processing Record 518 of Set 1 : marawi
# Processing Record 519 of Set 1 : saint albans
# Processing Record 520 of Set 1 : bavleny
# Processing Record 521 of Set 1 : port blair
# Processing Record 522 of Set 1 : aksu
# Processing Record 523 of Set 1 : ancud
# Processing Record 524 of Set 1 : badnawar
# Processing Record 525 of Set 1 : kontagora
# City not found. Skipping...
# Processing Record 526 of Set 1 : port-gentil
# Processing Record 527 of Set 1 : gaomi
# Processing Record 528 of Set 1 : yar-sale
# Processing Record 529 of Set 1 : mega
# Processing Record 530 of Set 1 : burley
# Processing Record 531 of Set 1 : uray
# Processing Record 532 of Set 1 : tucuman
# Processing Record 533 of Set 1 : acarau
# Processing Record 534 of Set 1 : salalah
# Processing Record 535 of Set 1 : maryville
# City not found. Skipping...
# Processing Record 536 of Set 1 : severnyy
# Processing Record 537 of Set 1 : yumen
# Processing Record 538 of Set 1 : moron
# Processing Record 539 of Set 1 : surok
# Processing Record 540 of Set 1 : harper
# Processing Record 541 of Set 1 : port hueneme
# Processing Record 542 of Set 1 : vad
# Processing Record 543 of Set 1 : morondava
# Processing Record 544 of Set 1 : santa marta
# Processing Record 545 of Set 1 : san ramon de la nueva oran
# Processing Record 546 of Set 1 : dunnville
# Processing Record 547 of Set 1 : deputatskiy
# Processing Record 548 of Set 1 : boddam
# Processing Record 549 of Set 1 : sechura
# Processing Record 550 of Set 1 : mathbaria
# Processing Record 551 of Set 1 : storozhevaya
# Processing Record 552 of Set 1 : cumana
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 553 of Set 1 : boende
# Processing Record 554 of Set 1 : hualmay
# Processing Record 555 of Set 1 : kawalu
# Processing Record 556 of Set 1 : usinsk
# Processing Record 557 of Set 1 : macae
# Processing Record 558 of Set 1 : mehamn
# Processing Record 559 of Set 1 : turayf
# Processing Record 560 of Set 1 : susangerd
# Processing Record 561 of Set 1 : mahon
# Processing Record 562 of Set 1 : netrakona
# Processing Record 563 of Set 1 : palmer
# Processing Record 564 of Set 1 : acapulco
# Processing Record 565 of Set 1 : satipo
# Processing Record 566 of Set 1 : naron
# Processing Record 567 of Set 1 : adrar
# Processing Record 568 of Set 1 : puerto escondido
# Processing Record 569 of Set 1 : pacific grove
# Processing Record 570 of Set 1 : panguna
# Processing Record 571 of Set 1 : brae
# Processing Record 572 of Set 1 : george
# Processing Record 573 of Set 1 : coahuayana
# Processing Record 574 of Set 1 : soure
# Processing Record 575 of Set 1 : ust-maya
# Processing Record 576 of Set 1 : meadow lake
# Processing Record 577 of Set 1 : eydhafushi
# Processing Record 578 of Set 1 : liku
# Processing Record 579 of Set 1 : bambanglipuro
# Processing Record 580 of Set 1 : zhanaozen
# City not found. Skipping...
# Processing Record 581 of Set 1 : asenovgrad
# Processing Record 582 of Set 1 : bentiu
# Processing Record 583 of Set 1 : trairi
# Processing Record 584 of Set 1 : salina

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# 1st, create a data frame
weather_df = pd.DataFrame({ 
                "City" : city_name,
                "Country" : country,
                "Date" : date,
                "Latitude" : lat,
                "Longtitude" : lon,
                "Cloudiness" : clouds,
                "Humidity" : humidity,
                "Max Temp" : max_temp,
                "Wind Speed" : wind_spd
})

weather_df.tail(10)
# Out:
#               City Country        Date  Latitude  Longtitude  Cloudiness  \
# 574       Ust-Maya      RU  1619373375   60.4167    134.5333          99
# 575    Meadow Lake      US  1619373375   34.8014   -106.5436          20
# 576     Eydhafushi      MV  1619373375    5.1033     73.0708          22
# 577           Liku      ID  1619373376   -0.7275    119.8922          85
# 578  Bambanglipuro      ID  1619372996   -7.9500    110.2833          93
# 579     Zhangaözen      KZ  1619373376   43.3000     52.8000          27
# 580     Asenovgrad      BG  1619373377   42.0167     24.8667          21
# 581         Bentiu      SS  1619373000    9.2333     29.8333          71
# 582         Trairi      BR  1619372980   -3.2778    -39.2689          85
# 583         Salina      US  1619373377   38.8403    -97.6114           1
#
#      Humidity  Max Temp  Wind Speed
# 574        98    270.00        1.07
# 575        15    299.26        4.63
# 576        73    301.76        2.26
# 577        89    297.24        1.47
# 578        84    297.56        2.05
# 579        31    293.17        1.86
# 580        50    287.15        3.09
# 581        54    301.25        3.64
# 582        68    301.78        4.33
# 583        49    296.48        9.77

# %%
# Save Data to csv
weather_df.to_csv("weather_data.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# use loc to find if there are any cities with humidity over 100%
extrm_hum = weather_df.loc[weather_df["Humidity"] >= 100, :]
extrm_hum.head()
### There are no cities with humidity above 100% in this dataset ###
# Out:
#            City Country        Date  Latitude  Longtitude  Cloudiness  \
# 65    Jyvaskyla      FI  1619373242   62.2415     25.7209          90
# 79       Neiafu      TO  1619373245  -18.6500   -173.9833          40
# 114     Husavik      IS  1619372911   66.0449    -17.3389          90
# 227  Volnovakha      UA  1619373277   47.6010     37.4967          64
# 270       Cooma      AU  1619373288  -36.2333    149.1333          19
#
#      Humidity  Max Temp  Wind Speed
# 65        100    275.37        5.14
# 79        100    294.15        1.99
# 114       100    277.15        7.72
# 227       100    282.59        1.34
# 270       100    274.15        1.02

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#x is the independant (latitude) variable, while y is the dependant (temp) variable
temp = weather_df['Max Temp']
lati = weather_df['Latitude']

#set the variables, the labels, and title while calling the plot
x_values = lati
y_values = temp
plt.scatter(x_values, y_values, s = 3, color = 'blue')
plt.title('Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temps (standard units)')

#save image and show plot
plt.savefig("../Resources/lat_temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#x is the independant (latitude) variable, while y is the dependant (humidity) variable
humi = weather_df['Humidity']
lati = weather_df['Latitude']

#set the variables, the labels, and title while calling the plot
x_values = lati
y_values = humi
plt.scatter(x_values, y_values,s = 3, color = 'blue')
plt.title('Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

#save image and show plot
plt.savefig("../Resources/lat_humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#x is the independant (latitude) variable, while y is the dependant (cloudiness) variable
cloud = weather_df['Cloudiness']
lati = weather_df['Latitude']

#set the variables, the labels, and title while calling the plot
x_values = lati
y_values = cloud
plt.scatter(x_values, y_values,s = 3, color = 'blue')
plt.title('Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

#save image and show plot
plt.savefig("../Resources/lat_cloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#x is the independant (latitude) variable, while y is the dependant (wind speed) variable
windi = weather_df['Wind Speed']
lati = weather_df['Latitude']

#set the variables, the labels, and title while calling the plot
x_values = lati
y_values = windi
plt.scatter(x_values, y_values,s = 3, color = 'blue')
plt.title('Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

#save image and show plot
plt.savefig("../Resources/lat_wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#need to create data for both northern and southern hemispheres prior to plotting regression
n_hemi = weather_df.loc[weather_df["Latitude"] >= 0] #find values greater than 0
s_hemi = weather_df.loc[weather_df["Latitude"] < 0] #find values less than 0
#n_hemi
#s_hemi - called both to check data

n_lat = n_hemi['Latitude']
s_lat = s_hemi['Latitude']
n_temp = n_hemi['Max Temp']
s_temp = s_hemi['Max Temp']
n_humi = n_hemi['Humidity']
s_humi = s_hemi['Humidity']

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#xvalues = independant variable (lat), while yvalues remain dependant (temp)
x_values = n_lat
y_values = n_temp


#set details for plot and regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = 'green')
plt.plot(x_values, regress_values, 'r-')
plt.title('Northern Hemisphere - Max Temp vs. Latitude')
plt.xlabel('Northern Hemisphere Latitudes')
plt.ylabel('Max Temperatures (standard units)')
plt.annotate(line_eq,(5,255),fontsize=15, color='red')

#save image and show plot
plt.savefig("../Resources/nh_temp_regress.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = s_lat
y_values = s_temp


#set details for plot and regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = 'green')
plt.plot(x_values, regress_values, 'r-')
plt.title('Southern Hemisphere - Max Temp vs. Latitude')
plt.xlabel('Southern Hemisphere Latitudes')
plt.ylabel('Max Temperatures (standard units)')
plt.annotate(line_eq,(5,255),fontsize=15, color='red')

#save image and show plot
plt.savefig("../Resources/sh_temp_regress.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = n_lat
y_values = n_humi


#set details for plot and regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = 'green')
plt.plot(x_values, regress_values, 'r-')
plt.title('Northern Hemisphere - Humidity vs. Latitude')
plt.xlabel('Northern Hemisphere Latitudes')
plt.ylabel('Humidity')
plt.annotate(line_eq,(45,20),fontsize=15, color='red')

#save image and show plot
plt.savefig("../Resources/nh_humi_regress.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = s_lat
y_values = s_humi


#set details for plot and regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = 'green')
plt.plot(x_values, regress_values, 'r-')
plt.title('Southern Hemisphere - Humidity vs. Latitude')
plt.xlabel('Southern Hemisphere Latitudes')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-55,25),fontsize=15, color='red')

#save image and show plot
plt.savefig("../Resources/sh_humi_regress.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = n_lat
y_values = n_cloud


#set details for plot and regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = 'green')
plt.plot(x_values, regress_values, 'r-')
plt.title('Southern Hemisphere - Humidity vs. Latitude')
plt.xlabel('Southern Hemisphere Latitudes')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-55,25),fontsize=15, color='red')

#save image and show plot
plt.savefig("../Resources/sh_humi_regress.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = s_lat
y_values = s_cloud


#set details for plot and regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = 'green')
plt.plot(x_values, regress_values, 'r-')
plt.title('Southern Hemisphere - Cloudiness vs. Latitude')
plt.xlabel('Southern Hemisphere Latitudes')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-55,25),fontsize=15, color='red')

#save image and show plot
plt.savefig("../Resources/sh_cloud_regress.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = s_lat
y_values = s_wind


#set details for plot and regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = 'green')
plt.plot(x_values, regress_values, 'r-')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude')
plt.xlabel('Southern Hemisphere Latitudes')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(-55,25),fontsize=15, color='red')

#save image and show plot
plt.savefig("../Resources/sh_wind_regress.png")
plt.show()
